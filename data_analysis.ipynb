# %% [markdown]
# ## Data Analysis
# We start our analysis by importing required libraries:

# %%
# %matplotlib inline
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt; plt.style.use('seaborn-colorblind')
import seaborn as sns; sns.set(style="ticks", color_codes=True)
#import time
#from datetime import datetime as dt

#from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
#from sklearn.model_selection import train_test_split
#from IPython.display import display
#from sklearn import metrics

#from fastai.tabular import *

#import os
#from IPython.display import display
pd.set_option('display.max_columns', None) # display all columns

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# We load the train data set:

# %%
PATH = 'train.txt'
column_names = ('Unit No','Time (in cycles)','Op Settings 1','Operational Settings 2','Operational Settings 3','Sensor 1','Sensor 2','Sensor 3','Sensor 4','Sensor 5','Sensor 6','Sensor 7','Sensor 8','Sensor 9','Sensor 10','Sensor 11','Sensor 12','Sensor 13','Sensor 14','Sensor 15','Sensor 16','Sensor 17','Sensor 18','Sensor 19','Sensor 20','Sensor 21')
df = pd.read_table(PATH, delim_whitespace=True, names=column_names)

#df = pd.read_csv(PATH, parse_dates = True, date_parser = 'datetime')

# %%
df.head()
# Out:
#    Unit No  Time (in cycles)  Op Settings 1  Operational Settings 2  \
# 0        1                 1        10.0047                  0.2501
# 1        1                 2         0.0015                  0.0003
# 2        1                 3        34.9986                  0.8401
# 3        1                 4        20.0031                  0.7005
# 4        1                 5        42.0041                  0.8405
#
#    Operational Settings 3  Sensor 1  Sensor 2  Sensor 3  Sensor 4  Sensor 5  \
# 0                    20.0    489.05    604.13   1499.45   1309.95     10.52
# 1                   100.0    518.67    642.13   1584.55   1403.96     14.62
# 2                    60.0    449.44    555.42   1368.17   1122.49      5.48
# 3                     0.0    491.19    607.03   1488.44   1249.18      9.35
# 4                    40.0    445.00    549.52   1354.48   1124.32      3.91
#
#    Sensor 6  Sensor 7  Sensor 8  Sensor 9  Sensor 10  Sensor 11  Sensor 12  \
# ...

# %% [markdown]
# Visualize sensor data of one engine:

# %%
df_example = df[df['Unit No'] <= 1]

# %%
plt.figure(figsize=(15,21))
for i in range(1,22):# (1,22)
    plt.subplot(22, 1, i)
    ax = sns.lineplot(x=df_example['Time (in cycles)'], y = df_example.iloc[:,i+4], data=df_example)
